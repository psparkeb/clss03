# %% [markdown]
# <a href="https://colab.research.google.com/github/psparkeb/clss03/blob/main/class03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#API (Application Programming Interface): 내가 얼굴 인식 기능을 만든다고 했을 때 처음부터 다 만들 필요 없고 만들어져있는 것을 api호출해서 그대로 가져와 쓸 수 있음.
                                        # 개선해서 쓴 후 다시 깃허브에 올리면 다른 사람들이 사용하고 이런 식으로 선순환이 이루어짐. 사용하려면 네이버에 개발자 등록 후 사용 가능.
                                        # 네이버 개발자 센터> 내 어플리케이션 > n9dL4RZhfgtl7yXdjqL7 > KEG9ebW6CV

# %%
import os
import sys
import requests
client_id = "n9dL4RZhfgtl7yXdjqL7"
client_secret = "KEG9ebW6CV"
url = "https://openapi.naver.com/v1/vision/face" # 얼굴감지
#url = "https://openapi.naver.com/v1/vision/celebrity" // 유명인 얼굴인식
files = {'image': open('family.jpg', 'rb')}
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }
response = requests.post(url,  files=files, headers=headers)
rescode = response.status_code
if(rescode==200):
    print (response.text)
else:
    print("Error Code:" + rescode)
# Out:
# {"info":{"size":{"width":1200,"height":847},"faceCount":7},"faces":[{"roi":{"x":341,"y":279,"width":60,"height":60},"landmark":{"leftEye":{"x":357,"y":292},"rightEye":{"x":384,"y":295},"nose":{"x":370,"y":308},"leftMouth":{"x":358,"y":324},"rightMouth":{"x":381,"y":325}},"gender":{"value":"male","confidence":0.999998},"age":{"value":"31~35","confidence":0.577669},"emotion":{"value":"neutral","confidence":0.999998},"pose":{"value":"frontal_face","confidence":0.999404}},{"roi":{"x":836,"y":266,"width":59,"height":59},"landmark":{"leftEye":{"x":856,"y":284},"rightEye":{"x":882,"y":282},"nose":{"x":870,"y":298},"leftMouth":{"x":859,"y":313},"rightMouth":{"x":882,"y":311}},"gender":{"value":"male","confidence":0.999996},"age":{"value":"38~42","confidence":0.331422},"emotion":{"value":"smile","confidence":0.747392},"pose":{"value":"frontal_face","confidence":0.995238}},{"roi":{"x":518,"y":251,"width":51,"height":51},"landmark":{"leftEye":{"x":532,"y":263},"rightEye":{"x":554,"y":264},"nose
# ...

# %%
import matplotlib.pyplot as plt # 그림 관련 라이브러리
import matplotlib.image as mpimg # 사진 관련 라이브러리

img=mpimg.imread('family.jpg')
plt.imshow(img)

# %%
#위에 사진 분석 결과값인 제이손?(자바 스크립트 형식)으로 나옴. 
import json
print(response)
# Out:
# <Response [200]>

# %%
print(response.text)
# Out:
# {"info":{"size":{"width":1200,"height":847},"faceCount":7},"faces":[{"roi":{"x":341,"y":279,"width":60,"height":60},"landmark":{"leftEye":{"x":357,"y":292},"rightEye":{"x":384,"y":295},"nose":{"x":370,"y":308},"leftMouth":{"x":358,"y":324},"rightMouth":{"x":381,"y":325}},"gender":{"value":"male","confidence":0.999998},"age":{"value":"31~35","confidence":0.577669},"emotion":{"value":"neutral","confidence":0.999998},"pose":{"value":"frontal_face","confidence":0.999404}},{"roi":{"x":836,"y":266,"width":59,"height":59},"landmark":{"leftEye":{"x":856,"y":284},"rightEye":{"x":882,"y":282},"nose":{"x":870,"y":298},"leftMouth":{"x":859,"y":313},"rightMouth":{"x":882,"y":311}},"gender":{"value":"male","confidence":0.999996},"age":{"value":"38~42","confidence":0.331422},"emotion":{"value":"smile","confidence":0.747392},"pose":{"value":"frontal_face","confidence":0.995238}},{"roi":{"x":518,"y":251,"width":51,"height":51},"landmark":{"leftEye":{"x":532,"y":263},"rightEye":{"x":554,"y":264},"nose
# ...

# %%
parsed=json.loads(response.text)
parsed
# Out:
# {'faces': [{'age': {'confidence': 0.577669, 'value': '31~35'},
#    'emotion': {'confidence': 0.999998, 'value': 'neutral'},
#    'gender': {'confidence': 0.999998, 'value': 'male'},
#    'landmark': {'leftEye': {'x': 357, 'y': 292},
#     'leftMouth': {'x': 358, 'y': 324},
#     'nose': {'x': 370, 'y': 308},
#     'rightEye': {'x': 384, 'y': 295},
#     'rightMouth': {'x': 381, 'y': 325}},
#    'pose': {'confidence': 0.999404, 'value': 'frontal_face'},
#    'roi': {'height': 60, 'width': 60, 'x': 341, 'y': 279}},
#   {'age': {'confidence': 0.331422, 'value': '38~42'},
#    'emotion': {'confidence': 0.747392, 'value': 'smile'},
#    'gender': {'confidence': 0.999996, 'value': 'male'},
#    'landmark': {'leftEye': {'x': 856, 'y': 284},
#     'leftMouth': {'x': 859, 'y': 313},
#     'nose': {'x': 870, 'y': 298},
#     'rightEye': {'x': 882, 'y': 282},
#     'rightMouth': {'x': 882, 'y': 311}},
#    'pose': {'confidence': 0.995238, 'value': 'frontal_face'},
# ...

# %%
print(json.dumps(parsed, indent=4))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 1200,
#             "height": 847
#         },
#         "faceCount": 7
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 341,
#                 "y": 279,
#                 "width": 60,
#                 "height": 60
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 357,
#                     "y": 292
#                 },
#                 "rightEye": {
#                     "x": 384,
#                     "y": 295
#                 },
#                 "nose": {
#                     "x": 370,
#                     "y": 308
#                 },
#                 "leftMouth": {
#                     "x": 358,
#                     "y": 324
#                 },
#                 "rightMouth": {
#                     "x": 381,
#                     "y": 325
#                 }
#             },
#             "gender": {
# ...

# %%
#dict 다루기, 순서가 없음. 따라서 인덱싱 불가, 슬라이싱 불가
dict={'Name':'pink','Age':23, 'Class':['beginner','blog']}
dict
# Out:
# {'Age': 23, 'Class': ['beginner', 'blog'], 'Name': 'pink'}

# %%
dict.keys()
# Out:
# dict_keys(['Name', 'Age', 'Class'])

# %%
dict.values()
# Out:
# dict_values(['pink', 23, ['beginner', 'blog']])

# %%
dict.items()
# Out:
# dict_items([('Name', 'pink'), ('Age', 23), ('Class', ['beginner', 'blog'])])

# %%
dict['Class']
# Out:
# ['beginner', 'blog']

# %%
dict.get('Class')
# Out:
# ['beginner', 'blog']

# %%
dict['Clss']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-2244b7e9a6e5> in <module>()
# ----> 1 dict['Clss']
#
# KeyError: 'Clss'

# %%
dict.get('Clas')

# %%
type(parsed)

# %%
parsed.keys()
# Out:
# dict_keys(['info', 'faces'])

# %%
parsed.values()
# Out:
# dict_values([{'size': {'width': 1200, 'height': 847}, 'faceCount': 7}, [{'roi': {'x': 341, 'y': 279, 'width': 60, 'height': 60}, 'landmark': {'leftEye': {'x': 357, 'y': 292}, 'rightEye': {'x': 384, 'y': 295}, 'nose': {'x': 370, 'y': 308}, 'leftMouth': {'x': 358, 'y': 324}, 'rightMouth': {'x': 381, 'y': 325}}, 'gender': {'value': 'male', 'confidence': 0.999998}, 'age': {'value': '31~35', 'confidence': 0.577669}, 'emotion': {'value': 'neutral', 'confidence': 0.999998}, 'pose': {'value': 'frontal_face', 'confidence': 0.999404}}, {'roi': {'x': 836, 'y': 266, 'width': 59, 'height': 59}, 'landmark': {'leftEye': {'x': 856, 'y': 284}, 'rightEye': {'x': 882, 'y': 282}, 'nose': {'x': 870, 'y': 298}, 'leftMouth': {'x': 859, 'y': 313}, 'rightMouth': {'x': 882, 'y': 311}}, 'gender': {'value': 'male', 'confidence': 0.999996}, 'age': {'value': '38~42', 'confidence': 0.331422}, 'emotion': {'value': 'smile', 'confidence': 0.747392}, 'pose': {'value': 'frontal_face', 'confidence': 0.995238}}, {'roi': 
# ...

# %%
parsed['info']
# Out:
# {'faceCount': 7, 'size': {'height': 847, 'width': 1200}}

# %%
parsed['faces'][0]
# Out:
# {'age': {'confidence': 0.577669, 'value': '31~35'},
#  'emotion': {'confidence': 0.999998, 'value': 'neutral'},
#  'gender': {'confidence': 0.999998, 'value': 'male'},
#  'landmark': {'leftEye': {'x': 357, 'y': 292},
#   'leftMouth': {'x': 358, 'y': 324},
#   'nose': {'x': 370, 'y': 308},
#   'rightEye': {'x': 384, 'y': 295},
#   'rightMouth': {'x': 381, 'y': 325}},
#  'pose': {'confidence': 0.999404, 'value': 'frontal_face'},
#  'roi': {'height': 60, 'width': 60, 'x': 341, 'y': 279}}

# %%
parsed['faces'][0]['age']
# Out:
# {'confidence': 0.577669, 'value': '31~35'}

# %%
parsed['faces'][0]['gender']
# Out:
# {'confidence': 0.999998, 'value': 'male'}

# %%
parsed['faces'][0]['emotion']
# Out:
# {'confidence': 0.999998, 'value': 'neutral'}

# %%
parsed['faces'][0]['roi']
# Out:
# {'height': 60, 'width': 60, 'x': 341, 'y': 279}

# %%
import matplotlib.patches as patches
import matplotlib.pyplot as plt

img = mpimg.imread('family.jpg')

fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(img)

for each in parsed['faces']:
  x,y,w,h = each['roi'].values()
  gender, gender_c = each['gender'].values()
  emotion, emotion_c = each['emotion'].values()
  age, age_c = each['age'].values()

  rect_face = patches.Rectangle((x,y),w,h,
                                edgecolor = 'r',
                                facecolor = 'none'
                                )
  anno = gender + ',' +  '\n' + age + ',' +  '\n' + emotion + ',' + '\n'
  plt.text(x, y+h+100, anno, color='blue')
  ax.add_patch(rect_face)

# %%
import matplotlib.patches as patches
import matplotlib.pyplot as plt

img = mpimg.imread('family.jpg')

fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(img)

for each in parsed['faces']:
  x,y,w,h = each['roi'].values()
  gender, gender_c = each['gender'].values()
  emotion, emotion_c = each['emotion'].values()
  age, age_c = each['age'].values()

  rect_face = patches.Rectangle((x,y),w,h,
                                edgecolor = 'r',
                                facecolor = 'none'
                                )
  anno = gender + ',' +  str(gender_c)+ '\n' + age + ',' + str(age_c)+ '\n' + emotion + ',' + str(emotion_c)+ '\n'
  plt.text(x, y+h+100, anno, color='blue')
  ax.add_patch(rect_face)

# %%
import os
import sys
import requests
client_id = "n9dL4RZhfgtl7yXdjqL7"
client_secret = "KEG9ebW6CV"
url = "https://openapi.naver.com/v1/vision/face" # 얼굴감지
#url = "https://openapi.naver.com/v1/vision/celebrity" // 유명인 얼굴인식
files = {'image': open('myface.jpg', 'rb')}
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }
response = requests.post(url,  files=files, headers=headers)

import json
parsed=json.loads(response.text)

import matplotlib.patches as patches
import matplotlib.pyplot as plt

img = mpimg.imread('myface.jpg')

fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(img)

for each in parsed['faces']:
  x,y,w,h = each['roi'].values()
  gender, gender_c = each['gender'].values()
  emotion, emotion_c = each['emotion'].values()
  age, age_c = each['age'].values()

  rect_face = patches.Rectangle((x,y),w,h,
                                edgecolor = 'r',
                                facecolor = 'none'
                                )
  anno = gender + ',' +  str(gender_c)+ '\n' + age + ',' + str(age_c)+ '\n' + emotion + ',' + str(emotion_c)+ '\n'
  plt.text(x, y+h+100, anno, color='white')
  ax.add_patch(rect_face)

# %%
# import os
# import sys
# import requests
# client_id = "n9dL4RZhfgtl7yXdjqL7"
# client_secret = "KEG9ebW6CV"
# #url = "https://openapi.naver.com/v1/vision/face" # 얼굴감지
# url = "https://openapi.naver.com/v1/vision/celebrity" # 유명인 얼굴인식
# files = {'image': open('myface.jpg', 'rb')}
# headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }
# response = requests.post(url,  files=files, headers=headers)

# import json
# parsed=json.loads(response.text)
# print(parsed)

# #'value': '김희애', 'confidence': 0.23042

# import matplotlib.patches as patches
# import matplotlib.pyplot as plt

# img = mpimg.imread('myface.jpg')

# fig, ax = plt.subplots(figsize=(10,10))
# ax.imshow(img)

# a,b=parsed['faces'][0]['celebrity'].values()
# x,y,w,h = each['roi'].values()
# rect_face = patches.Rectangle((x,y),w,h,edgecolor = 'r',facecolor = 'none')
# anno = "연예인"+"("+value+")"+"를 ("+str(celebrity_c)+")"+"%만큼 닮았습니다.")
# plt.text(x, y+h+100, anno, color='blue')
# ax.add_patch(rect_face)
# Out:
#   File "<ipython-input-45-88cc8ca42afe>", line 28
#     anno = "연예인"+"("+value+")"+"를 ("+confidence+")"+"%만큼 닮았습니다.")
#                                                                 ^
# SyntaxError: invalid syntax

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

import matplotlib.patches as patches
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

img = mpimg.imread('myface.jpg')

fig, ax = plt.subplots(figsize = (10,10))
ax.imshow(img)

a,b = parsed["faces"][0]['celebrity'].values()

b = round(b*100)


# k = "연예인 {}를 {}%의 확률로 닮았습니다.".format(a,b)
# anno = k.decode("utf-8")
anno = "연예인 {}를 {}%의 확률로 닮았습니다.".format(a,b)
plt.text(300, 600, anno, color = 'blue')
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded
# ...
